# %%
import os
from pathlib import Path

import pandas as pd

# %%
# RUN ONCE: change working directory to project root
cwd = Path.cwd()

pwd = cwd.parent

os.chdir(pwd)
print(f"Changed working directory to {pwd}")

if Path.cwd() != pwd:
    raise RuntimeError(f"Failed to change working directory to {pwd}")
# Out:
# Changed working directory to /Users/jdk/projects/team-builder

# %%
attributes_df = pd.read_csv('data/player-attributes/portal_2025_transfers_1218_run5.csv')

# %%
full_attributes_df = pd.read_excel('data/player-attributes/2024-2025 Player Database v2_FILLED_attempt2.xlsx')

# %%
stats_df = pd.read_excel('data/player-stats/2024 PFF End of Regular Season.xlsx')
